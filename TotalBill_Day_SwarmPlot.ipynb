# %%
'''
    @Author: Sudhanshu Kumar
    @Date: 30-10-2024
    @Last Modified by: Sudhanshu Kumar
    @Last Modified time: 30-10-2024
    @Title : Creating swarm plot for total bill against day

'''
# Out:
# '\n    @Author: Sudhanshu Kumar\n    @Date: 30-10-2024\n    @Last Modified by: Sudhanshu Kumar\n    @Last Modified time: 30-10-2024\n    @Title : Creating swarm plot for total bill against day\n\n'

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

# %%
def plot(file):
    """
    Description:
        Function for swarm plot of total bill by day
    Parameters:
        file: path to .csv file
    returns:
        nothing
    """
    df = extractData(file)
    sns.swarmplot(x='day', y='total_bill', data=df, palette='viridis')
    plt.show()

# %%
def extractData(file):
    """
    Description:
        Function to extract data from .csv file
    Parameters:
        file: file path
    returns:
        required data
    """
    df = pd.read_csv(file)

    
    return df

# %%
def main():
    #print(extractData('titanic.csv'))
    plot('tips.csv')

# %%
if __name__=="__main__":
    main()
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_11452\3929785858.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='day', y='total_bill', data=df, palette='viridis')
