# %%
'''
    @Author: Sudhanshu Kumar
    @Date: 18-10-2024
    @Last Modified by: Sudhanshu Kumar
    @Last Modified time: 18-10-2024
    @Title : Reading data from .csv file

'''
# Out:
# '\n    @Author: Sudhanshu Kumar\n    @Date: 18-10-2024\n    @Last Modified by: Sudhanshu Kumar\n    @Last Modified time: 18-10-2024\n    @Title : Reading data from .csv file\n\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def read_financial_data(filename):
    """
    Description:
        This function read the data from .csv file
    Parameters:
        file: Name and path of the .csv file
    Returns:
        x_values: values for x axis
        y_values: values for y axis
    """
    # Load the data into a DataFrame
    df = pd.read_csv(filename)
    
    # Convert the 'Date' column to datetime format
    df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%y')
    
    return df

# %%
def main():
    # Read financial data from fdata.csv
    df = read_financial_data('fdata.csv')

    # Set the date as the index
    df.set_index('Date', inplace=True)

    # Plot the line charts for Open, High, Low, Close prices
    plt.figure(figsize=(10, 5))  # Set the figure size

    plt.plot(df.index, df['Open'], marker='o', label='Open')
    plt.plot(df.index, df['High'], marker='o', label='High')
    plt.plot(df.index, df['Low'], marker='o', label='Low')
    plt.plot(df.index, df['Close'], marker='o', label='Close')

    # Label the axes and title
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.title('Financial Data of Alphabet Inc. (Oct 3, 2016 - Oct 7, 2016)')
    
    # Rotate the x-axis labels for better readability
    plt.xticks(rotation=45)

    # Show legend
    plt.legend()

    # Add grid for better readability
    plt.grid()
    
    # Display the plot
    plt.tight_layout()  # Adjust layout to prevent clipping
    plt.show()

# %%
if __name__=="__main__":
    main()
