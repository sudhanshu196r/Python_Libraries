# %%
'''
    @Author: Sudhanshu Kumar
    @Date: 30-10-2024
    @Last Modified by: Sudhanshu Kumar
    @Last Modified time: 30-10-2024
    @Title : Creating line and scatter plot using plotly for 100 random

'''
# Out:
# '\n    @Author: Sudhanshu Kumar\n    @Date: 30-10-2024\n    @Last Modified by: Sudhanshu Kumar\n    @Last Modified time: 30-10-2024\n    @Title : Creating line and scatter plot using plotly for 100 random\n\n'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random x and y coordinates
x = np.random.rand(100)
y = np.random.rand(100)

# Create the plot
plt.figure(figsize=(10, 5))

# Scatter plot
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.scatter(x, y, color='blue', alpha=0.6, edgecolor='k')
plt.title('Scatter Plot')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')

# Line plot
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.plot(x, y, color='red', marker='o', linestyle='-', markersize=4, alpha=0.7)
plt.title('Line Plot')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')

plt.tight_layout()
plt.show()
